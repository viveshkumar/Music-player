# %% [markdown]
# <a href="https://colab.research.google.com/github/viveshkumar/Music-player/blob/main/EDA_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  **Global Terrorism Dataset**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -**  - Vivesh Kumar
# ##### **Team Member 2 -**  - Rohit Kumar
# ##### **Team Member 3 -**  - Abhishek Singh
# ##### **Team Member 4 -**  - Hariom Sharma

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# #Data Preprocessing:
#
#
#
# 1.   Getting the Dataset
# 2.   importing Dataset
# 3.   importing librareis
# 4.   Finding Missing Data
# 1.   Encoding Categrocal Data
# 2.   Data Cleaning and Feature Engineering
#
#
# #Explore and analyze the data to discover key findings pertaining to terrorist activities
#
# The Goblal Terrorism Dataset (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017.
#
# The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks.
#
# The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.
#
#
# ##### **Supervise Machine learning algorithms and implementation :**
#
# 1.   Logistic regression
# 2.   Random Forest Classifier
# 3.   XG Boost Classifier

# %% [markdown]
# # **GitHub Link -**
# https://github.com/viveshkumar

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# 1.   Terrorist Attacks Per Year?
# 2.   Region via Number of Attacks?
#
# 3.   Most Frequent Used Weapon in Attacks?
# 4.   Most Frequent Target of Terrorist?
#
#
# 5.   Most number of Attacks?
# 6.   Successfull Terrorist Attacks?
#
# 7.   Number of multiple attacks?
# 8.   Number of Sucide Attacks?
#
# 9.   Terrorist Activities by region in each Year?
# 10.   Top 10 Coutries able to successfull Tackle Terrorist attacks(more the 5 attackS)?
#
# 11.   Top 10 Coutries unable to successfull Tackle Terrorist attacks(more the 5 attackS)?
#
# 12.   Top 30 Countey via Numbers of Attacks
# 13.   Most Frequent Type of Attacks

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as nd
import pandas as pd
import missingno as msno
import seaborn as sbn
# %matplotlib inline
import matplotlib.pyplot as plt
# !pip install folium
import folium as mp
import os
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path='/content/Global Terrorism Data.csv'

# %%
df=pd.read_csv(file_path,encoding=('ISO-8859-1'),low_memory=False)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head().iloc[:,100:]
# Out:
#    nkillter  nwound  nwoundus  nwoundte  property  propextent propextent_txt  \
# 0       NaN     0.0       NaN       NaN         0         NaN            NaN
# 1       NaN     0.0       NaN       NaN         0         NaN            NaN
# 2       NaN     0.0       NaN       NaN         0         NaN            NaN
# 3       NaN     NaN       NaN       NaN         1         NaN            NaN
# 4       NaN     NaN       NaN       NaN         1         NaN            NaN
#
#    propvalue propcomment  ishostkid  ...  addnotes  scite1  scite2  scite3  \
# 0        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
# 1        NaN         NaN        1.0  ...       NaN     NaN     NaN     NaN
# 2        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
# 3        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
# 4        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
#
# ...

# %%
df.tail(10)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181681  2.017120e+11   2017      12    31        NaN         0        NaN
# 181682  2.017120e+11   2017      12    31        NaN         0        NaN
# 181683  2.017120e+11   2017      12    31        NaN         0        NaN
# 181684  2.017120e+11   2017      12    31        NaN         0        NaN
# 181685  2.017120e+11   2017      12    31        NaN         0        NaN
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ...  \
# 181681      160  Philippines       5  ...
# 181682       98        Italy       8  ...
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
print("This is the checking of data type:----")
print(type(df))# checking type of the data
print('\n')

print('\n')
print("checking the corelation between the columns")
print(df.corr())# checking the corelation between the columns, 
#few observation made like event id is having 90% +ve corelation with iyear.
# showing strong corelation in eventid and iyear similarly as others shown in below.
# Out:
# This is the checking of data type:----
# <class 'pandas.core.frame.DataFrame'>
#
#
#
#
# checking the corelation between the columns
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002705  0.018270  0.091762 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002705  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018270  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091762  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181613 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077851 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# ...

# %%
df.summary# tells the summary of data
# Out:
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
#                                 ...
# 181686    12/31/2017: Assailants opened fire on a Somali...
# 181687    12/31/2017: Assailants launched mortars at the...
# 181688    12/31/2017: Assailants set fire to houses in K...
# 181689    12/31/2017: Assailants threw a grenade at a Fo...
# 181690    12/31/2017: An explosive device was discovered...
# Name: summary, Length: 181691, dtype: object

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 181686    False
# 181687    False
# 181688    False
# 181689    False
# 181690    False
# Length: 181691, dtype: bool

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_value=df.isnull()
sum_of_null=df.isnull().sum()
print(null_value)
print(sum_of_null)
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# ...

# %% [markdown]
# #% of null per column

# %%
null_value_percolumn=df.isnull().sum()/df.shape[0]*100# checking null % in column wise
null_value_percolumn
# Out:
# eventid        0.000000
# iyear          0.000000
# imonth         0.000000
# iday           0.000000
# approxdate    94.914993
#                 ...
# INT_LOG        0.000000
# INT_IDEO       0.000000
# INT_MISC       0.000000
# INT_ANY        0.000000
# related       86.219461
# Length: 135, dtype: float64

# %%
columns_to_drop =null_value_percolumn [null_value_percolumn >65].keys() # storing null values in a variable having more than 10% null values
columns_to_drop
# Out:
# Index(['approxdate', 'resolution', 'location', 'alternative',
#        'alternative_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3',
#        'attacktype3_txt', 'targtype2', 'targtype2_txt', 'targsubtype2',
#        'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt',
#        'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt',
#        'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gsubname', 'gname2',
#        'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain2',
#        'guncertain3', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim',
#        'weaptype2', 'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt',
#        'weaptype3', 'weaptype3_txt', 'weapsubtype3', 'weapsubtype3_txt',
#        'weaptype4', 'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt',
#        'propvalue', 'propcomment', 'nhostkid', 'nhostkidus', 'nhours', 'ndays',
# ...

# %%
after_droped_df = df.drop(columns= columns_to_drop) # storing in a variable having not null entirely

# %%
after_droped_df
# Out:
#              eventid  iyear  imonth  iday  extended  country  \
# 0       1.970000e+11   1970       7     2         0       58
# 1       1.970000e+11   1970       0     0         0      130
# 2       1.970010e+11   1970       1     0         0      160
# 3       1.970010e+11   1970       1     0         0       78
# 4       1.970010e+11   1970       1     0         0      101
# ...              ...    ...     ...   ...       ...      ...
# 181686  2.017120e+11   2017      12    31         0      182
# 181687  2.017120e+11   2017      12    31         0      200
# 181688  2.017120e+11   2017      12    31         0      160
# 181689  2.017120e+11   2017      12    31         0       92
# 181690  2.017120e+11   2017      12    31         0      160
#
#                country_txt  region                   region_txt  \
# 0       Dominican Republic       2  Central America & Caribbean
# 1                   Mexico       1                North America
# ...

# %%
after_droped_df.isnull().sum() #we observe we still have null values
# Out:
# eventid     0
# iyear       0
# imonth      0
# iday        0
# extended    0
#            ..
# dbsource    0
# INT_LOG     0
# INT_IDEO    0
# INT_MISC    0
# INT_ANY     0
# Length: 62, dtype: int64

# %%
# Visualizing the missing values
missing_value=msno.matrix(df)
print(missing_value)
# Out:
# AxesSubplot(0.125,0.125;0.698618x0.755)

# %%
miss_bar_chart=msno.bar(df)
print(miss_bar_chart)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#visualizing the missing values by heatmap
plt.figure(figsize=(10,10))
df.corr()
msno.heatmap(df.corr())

# %% [markdown]
# # Heatmap
# Heatmap shows the correlation of missingness between every 2 columns. In our example, the correlation between AAWhiteSt-4 and SulphidityL-4 is 1 which means if one of them is present then the other one must be present.
#
#
# A value near -1 means if one variable appears then the other variable is very likely to be missing.
#
# A value near 0 means there is no dependence between the occurrence of missing values of two variables.
#
# A value near 1 means if one variable appears then the other variable is very likely to be present.

# %% [markdown]
# #After remove NaN Value

# %%
# after removing all null values
after_droped_df.dropna(inplace=True)
after_droped_df.isnull().sum()
# Out:
# eventid     0
# iyear       0
# imonth      0
# iday        0
# extended    0
#            ..
# dbsource    0
# INT_LOG     0
# INT_IDEO    0
# INT_MISC    0
# INT_ANY     0
# Length: 62, dtype: int64

# %%
# hetmap after removing all null values
sbn.heatmap(after_droped_df.isnull())

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
# The Global Terrorism Database contain information on terrorist events around the world from 1970 through 2017. Unlike many other event databases, the GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and includes more than 1,70,000 case.So,by first look we can see Global terrorism data set contain 181691 row and 135 columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# type of variable
print(df.dtypes)
# Out:
# eventid       float64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG         int64
# INT_IDEO        int64
# INT_MISC        int64
# INT_ANY         int64
# related        object
# Length: 135, dtype: object

# %%
# Dataset Describe
print("This is the decription of satistics of the data")
print(df.describe()) # Asking the discriptive statistics of the data
# Out:
# This is the decription of satistics of the data
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# ...

# %% [markdown]
# #Column Selection or rejection

# %%
# checking total number of columns I am having, turned out to be 44.
after_droped_df.columns.value_counts().sum()
# Out:
# 62

# %%
#Let seen what are the column out of 1351
after_droped_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude',
#        'longitude', 'specificity', 'vicinity', 'summary', 'crit1', 'crit2',
#        'crit3', 'doubtterr', 'multiple', 'success', 'suicide', 'attacktype1',
#        'attacktype1_txt', 'targtype1', 'targtype1_txt', 'targsubtype1',
#        'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt',
#        'gname', 'guncertain1', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'weaptype1', 'weaptype1_txt', 'weapsubtype1', 'weapsubtype1_txt',
#        'weapdetail', 'nkill', 'nkillus', 'nkillter', 'nwound', 'nwoundus',
#        'nwoundte', 'property', 'propextent', 'propextent_txt', 'ishostkid',
#        'ransom', 'scite1', 'scite2', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %%
# I identified and selected columns which required no change,
#and we dont need those either they containing demographic imformaton or they are giving not putting much contaxt to our analysis
# So let's remove them
# droping columns I will put inside list because there are more columns to remove as well can see above
after_droped_2=after_droped_df.drop(columns=['extended', 'country','region','specificity', 'vicinity', 'crit1', 'crit2', 'crit3',
       'doubtterr', 'multiple','weaptype1','attacktype1','targtype1','targsubtype1','natlty1', 'natlty1_txt',
       'guncertain1', 'individual', 
        'weaptype1','property', 'ishostkid', 'dbsource','INT_LOG', 
        'INT_IDEO', 'INT_MISC', 'INT_ANY'])

# %%
after_droped_2
# Out:
#              eventid  iyear  imonth  iday    country_txt  \
# 5       1.970010e+11   1970       1     1  United States
# 8       1.970010e+11   1970       1     2  United States
# 9       1.970010e+11   1970       1     3  United States
# 11      1.970010e+11   1970       1     6  United States
# 13      1.970010e+11   1970       1     9  United States
# ...              ...    ...     ...   ...            ...
# 179206  2.017090e+11   2017       9    27          Egypt
# 179230  2.017090e+11   2017       9    28    Philippines
# 180989  2.017120e+11   2017      12     2          Yemen
# 181239  2.017120e+11   2017      12    11          India
# 181411  2.017120e+11   2017      12    19          India
#
#                         region_txt         provstate         city   latitude  \
# 5                    North America          Illinois        Cairo  37.005105
# 8                    North America         Wisconsin      Madison  43.076592
# ...

# %%
after_droped_2.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'summary', 'success',
#        'suicide', 'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt',
#        'corp1', 'target1', 'gname', 'nperps', 'nperpcap', 'claimed',
#        'weaptype1_txt', 'weapsubtype1', 'weapsubtype1_txt', 'weapdetail',
#        'nkill', 'nkillus', 'nkillter', 'nwound', 'nwoundus', 'nwoundte',
#        'propextent', 'propextent_txt', 'ransom', 'scite1', 'scite2'],
#       dtype='object')

# %%
# after droping cheking the total no. of columns and rows available in df turned out to be 2574, 19
after_droped_2.shape
# Out:
# (880, 37)

# %%
# Remaning the all columns which is not null
 # Renaming in the form of dictionary

# %%
after_droped_2.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'summary', 'success',
#        'suicide', 'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt',
#        'corp1', 'target1', 'gname', 'nperps', 'nperpcap', 'claimed',
#        'weaptype1_txt', 'weapsubtype1', 'weapsubtype1_txt', 'weapdetail',
#        'nkill', 'nkillus', 'nkillter', 'nwound', 'nwoundus', 'nwoundte',
#        'propextent', 'propextent_txt', 'ransom', 'scite1', 'scite2'],
#       dtype='object')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
after_droped_2.nunique()
# Out:
# eventid             271
# iyear                47
# imonth               12
# iday                 32
# country_txt          48
# region_txt           10
# provstate           206
# city                549
# latitude            592
# longitude           591
# summary             875
# success               2
# suicide               2
# attacktype1_txt       7
# targtype1_txt        21
# targsubtype1_txt     82
# corp1               578
# target1             822
# gname               146
# nperps               30
# nperpcap             13
# claimed               3
# weaptype1_txt         5
# weapsubtype1         23
# weapsubtype1_txt     23
# weapdetail          579
# nkill                38
# nkillus               9
# nkillter              8
# nwound               43
# nwoundus             14
# nwoundte              5
# propextent            3
# propextent_txt        3
# ransom                3
# scite1              637
# scite2              696
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
after_droped_2=after_droped_2.rename(columns={
    'eventid':'event_id',
    'iyear':'year',
    'imonth':'month',
    'iday':'day',
    'country_txt':'country',
    'region_txt':'region',
       'provstate':'state',
       'attacktype1_txt':'attack_type',
    'targtype1_txt':'targ_type',
    'targsubtype1_txt':'targsub_type',
    'target1':'main_target',
       'gname':'gang_name',
    'weaptype1_txt':'weapon_type',
    'nkill':'number_of_kill',
    'nwound':'number_of_wound'
    
})

# %%
after_droped_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 880 entries, 5 to 181411
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   event_id          880 non-null    float64
#  1   year              880 non-null    int64
#  2   month             880 non-null    int64
#  3   day               880 non-null    int64
#  4   country           880 non-null    object
#  5   region            880 non-null    object
#  6   state             880 non-null    object
#  7   city              880 non-null    object
#  8   latitude          880 non-null    float64
#  9   longitude         880 non-null    float64
#  10  summary           880 non-null    object
#  11  success           880 non-null    int64
#  12  suicide           880 non-null    int64
#  13  attack_type       880 non-null    object
#  14  targ_type         880 non-null    object
#  15  targsub_type      880 non-null    object
# ...

# %%
after_droped_2.head()
# Out:
#         event_id  year  month  day        country         region      state  \
# 5   1.970010e+11  1970      1    1  United States  North America   Illinois
# 8   1.970010e+11  1970      1    2  United States  North America  Wisconsin
# 9   1.970010e+11  1970      1    3  United States  North America  Wisconsin
# 11  1.970010e+11  1970      1    6  United States  North America   Colorado
# 13  1.970010e+11  1970      1    9  United States  North America   Michigan
#
#        city   latitude   longitude  ... nkillus  nkillter  number_of_wound  \
# 5     Cairo  37.005105  -89.176269  ...     0.0       0.0              0.0
# 8   Madison  43.076592  -89.412488  ...     0.0       0.0              0.0
# 9   Madison  43.072950  -89.386694  ...     0.0       0.0              0.0
# 11   Denver  39.758968 -104.876305  ...     0.0       0.0              0.0
# 13  Detroit  42.331685  -83.047924  ...     0.0       0.0              0.0
#
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
# Global terrorism data set contains 135 columns.so in first step,we find out which column have less nun value and rename in that way,that it can be easily understand. In second step we creat a data frame with necessarly coulmns which is useful for our analysis,and with the help of these column we can plot differenr charts for data vizualization.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# #### ***Let's look year wise terrorism attacks***

# %%
# Chart - 1 visualization code
 # plotting using barplot year and number of attack happend.
x_year = after_droped_2['year'].unique()
y_year = after_droped_2['year'].value_counts().sort_index()
plt.figure(figsize=(14,8))
plt.bar(x_year, y_year)
plt.title('TERRORIST ATTACK PER YEAR')
plt.xlabel('YEAR OF ATTACK')
plt.ylabel('COUNTS OF ATTACKS')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# I choose bar chart because bar charts enable us to compare numerical values like integers and percentages.They use the length of each bar to represent the value of each variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
#
# *  According to above observation,it can be concluded that number of attack increased and decreased rapidly on 1970 to 2017 and where 1970 the max attacks year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# *   Yes, this is the very impactful and benificial of business becouse in the above char it is very clear that which year the attack is max and which year is attack less and visualyzation is also very attractive as well good

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Top 30 Countey via Numbers of Attacks

# %%
ax=plt.rcParams['figure.figsize'] = 22,8.27
ax=sbn.countplot(x='country_txt',data=df,order = df['country_txt'].value_counts().index[:30])
ax.set_xlabel('Country',fontsize=20)
plt.xticks(rotation = 75)
ax.set_ylabel('Count of Terrorist Attack',fontsize=20)
ax.set_title('Top 30 Countey via Numbers of Attacks',fontsize=22);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# we choose bar chart because it's give better visualization and understandable concept and compare number,they show lenth of the effected things.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# Through this bar chart we present that, what are top 30 countries which are mostly targeted by terrorist?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# This bar chart shows,which country are deeply affected by terrorist.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %%
# the max of attact which region?
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sbn.countplot(x='region_txt',data=df,order = df['region_txt'].value_counts().index)
ax.set_xlabel('Region',fontsize=18)
plt.xticks(rotation = 75)
ax.set_ylabel('Count of Terrorist Attack',fontsize=18)
ax.set_title('Region via Numbers of Attacks',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:
# we can easily understand which region has deeply effected with the help this bar chart and due to that reasion we used this bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# Through this bar chart we present that, what are top region effected  which are mostly targeted by terrorist?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# it is visualizing the which region is deeply effected.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sbn.countplot(x='weaptype1_txt',data=df,order = df['weaptype1_txt'].value_counts().index[:6])
ax.set_xlabel('Weapon',fontsize=18)
plt.xticks(rotation = 75)
ax.set_ylabel('Count',fontsize=18)
ax.set_title('Most Frequent Used Weapon in Attacks',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# bar chart is very userfriendly and we can visualization of data that's why we used the bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# Through this bar chart we present that, which weapon mostly used of terrorist?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# it is visualizing the which weapons are deeply used for attacks.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sbn.countplot(x='attacktype1_txt',data=df,order = df['attacktype1_txt'].value_counts().index)
ax.set_xlabel('Type of Attack',fontsize=18)
plt.xticks(rotation = 75)
ax.set_ylabel('Number of Times attacks',fontsize=18)
ax.set_title('Most Frequent Type of Attacks',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# I choose this bar chart to represent what type of attack is motly used by terrorist. since it present with the help of numerical values,bar chart is easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# This chart shows that Bombing/Explosion is type of attack mostly used by terrorist groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# This insight help to train our security forces against which type of terrorist attack.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sbn.countplot(x='targtype1_txt',data=df,order = df['targtype1_txt'].value_counts().index)
ax.set_xlabel('Type of Targets',fontsize=18)
plt.xticks(rotation = 75)
ax.set_ylabel('Count',fontsize=18)
ax.set_title('Most Frequent Target of Terrorist',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# i choose this bar chart to represent which place is most targeted by terrorist since it present with the help of numerical values,bar chart is easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# With the help from the chart,it is easy to understand that private citizens and property are mostly targeted by terrorists.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# This insight helps us to find answer of the question that where we put more securities.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
ax=plt.rcParams['figure.figsize'] = 16,12
ax=sbn.countplot(y='gname',data=df,order = df['gname'].value_counts().index[1:50])
ax.set_xlabel('Type of Targets',fontsize=18)
# plt.yticks(rotation = 75)
ax.set_ylabel('Terrorist Organisation',fontsize=18)
ax.set_title('Number of Attacks',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# i choose this bar chart to represent which terrorist organisation has done more attacks since it present with the help of numerical values,bar chart is easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# With the help of this chart,we can easily answer the question that which terrorist organostion is more dangerous and causes more number of attack.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# This insight helps us to understand,where terrorist organisation requires utter most attention.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
ax=df['success'].value_counts().plot(kind='pie')
ax.set_title('Successfull Terrorist Attack',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
ax=df['multiple'].value_counts().plot(kind='pie')
ax.set_title('Number of Multiple Attack',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
ax=after_droped_2['suicide'].value_counts().plot(kind='pie')
ax.set_title('Number of Sucide Attack',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
pd.crosstab(after_droped_2.year, after_droped_2.region).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities By Region In Each Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# We choose density plot graph to understand region wise terrorist attack because Density plots allow to visualize the distribution of a numeric variable for one or several groups. They are very well adapted for large datase.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# By this plot graph,we can see that Middle East and North Africa is the most affected region due to terrorism.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *Answer* Here
# This insight helps us to understand that, middle east,north africe,south east asia are the top 3 region where we need to put more resources to fight with terrorism.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
suceess_country=after_droped_2.groupby('country').agg({'event_id':'count','success':'sum'}).reset_index()
suceess_country.columns=['Country','Total_Attacks','Attack_Success']
suceess_country['Attack_Failed']=suceess_country['Total_Attacks']-suceess_country['Attack_Success']
suceess_country['Failure_Rate_Attack']=(suceess_country['Attack_Failed']/suceess_country['Total_Attacks'])*100
suceess_country['Success_Rate_Attack']=(suceess_country['Attack_Success']/suceess_country['Total_Attacks'])*100
suceess_country=suceess_country.round(2)

# %%
able_stop_terror_attack=suceess_country[suceess_country['Total_Attacks']>=5].sort_values('Failure_Rate_Attack',ascending=False )[:10]
plot_able_stop_terror_attack=able_stop_terror_attack.loc[:,['Country','Failure_Rate_Attack']]
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sbn.barplot(x='Country',y='Failure_Rate_Attack',data=plot_able_stop_terror_attack)
ax.set_xlabel('Countries',fontsize=18)
plt.xticks(rotation = 75)
ax.set_ylabel('Rate of Failure of Terror Attack',fontsize=18)
ax.set_title('Top 10 Countries Able to Successfull Tackle  Terrorist Attack("More Than 5 Attack")',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
unable_stop_terror_attack=suceess_country[suceess_country['Total_Attacks']>=5].sort_values('Success_Rate_Attack',ascending=False )[:10]
plot_unable_stop_terror_attack=unable_stop_terror_attack.loc[:,['Country','Success_Rate_Attack','Total_Attacks']]
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sbn.barplot(x='Country',y='Success_Rate_Attack',data=plot_unable_stop_terror_attack)
ax.set_xlabel('Countries',fontsize=18)
plt.xticks(rotation = 75)
ax.set_ylabel('Rate of Success of Terror Attack',fontsize=18)
ax.set_title('Top 10 Countries UNable to Successfully Tackle  Terrorist Attack("More Than 5 Attack")',fontsize=20);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
sbn.heatmap(after_droped_2[['year','number_of_kill','suicide']].corr(), annot=True, cmap = 'Reds') # cheking corelation

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
attack_per_year=after_droped_2.groupby(['year','targ_type','main_target','success','weapon_type','gang_name'])['event_id'].count().to_frame(name = 'Total_Attacks').reset_index()

# %%
ax =sbn.relplot(col="weapon_type", y="Total_Attacks",col_wrap=4, hue='weapon_type',x="year",kind='line', ci=None ,data=attack_per_year, height=3, aspect=1.5, legend=False)

# %%
ax = sbn.relplot(col="targ_type", y="Total_Attacks",col_wrap=5, hue='targ_type',x="year",kind='line', ci=None ,data=attack_per_year, height=3, aspect=1.5, legend=False)
# ax.tick_params(rotation=45)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
# ##most attacks
#
#
# *   Year with most attacks: 1970
# *   Country with most attacks: Iraq
# *   most type of attacks: Bombing/Explosion
#
# *   most target attacks: privet citizion & property
# *   most number of attacks: Taliban
#
# *   number of Sucide attacks: 0
# *   number of multiple attacks: 0
#
# *   most Country able to sucessful attacks: Belgium
#
# *   sucessful attacks: 1
# *   most weapon attacks: Explosives
#
# *   Region with the most attacks: Middle East & North Africa

# %% [markdown]
# ##After Attacks with years.
#
#
# *   number of attacks increased and decreased rapidly after 1970 to 2017 and the max attacks is 1970

# %% [markdown]
# **Few Observation about Al-Qaeda.**
#
# * Al-qaida group have done most killings.
# * Weapon used for killing is only two: 1)Explosives and 2)vehicle-borne explosive.
# * year 2001 more than 1 attack by Al- Qaeda.
# * Seems like USA and Al-Qaida were in war for some issue.

# %% [markdown]
# **Top active Terrorist group.**
#
#
# * Most active gangs are Taliban,CPI-Maoist,ISIL.
# * These gangs are using mostly Bombing/Explosion and Armed Assault.
# * We can conclude that most attacks and most killings are performed by ISIL followed by Taiban.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
